# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API__KEY"]=os.getenv("GROQ_API_KEY")
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("google_genai:gemini-2.5-flash")
model
# Out:
# ChatGoogleGenerativeAI(output_version=None, profile={'name': 'Gemini 2.5 Flash', 'release_date': '2025-03-20', 'last_updated': '2025-06-05', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), location=None, model='gemini-2.5-flash', client=<google.genai.client.Client object at 0x000001908CDDE7D0>, default_metadata=(), model_kwargs={})

# %%
response=model.invoke("hello how are you")
response
# Out:
# AIMessage(content="Hello! I'm an AI, so I don't experience feelings like humans do, but I'm operating perfectly and ready to assist you.\n\nHow are you doing today, and how can I help you?", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e5cdd-d9c2-7100-a7af-7e2a80317736-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5, 'output_tokens': 297, 'total_tokens': 302, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 252}})

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# 'Parrots talk due to a fascinating combination of **unique anatomy, advanced cognitive abilities, and their highly social nature.** It\'s not just random mimicry; there are strong biological and behavioral drivers behind it.\n\nHere\'s a breakdown of the key reasons:\n\n1.  **Unique Vocal Anatomy:**\n    *   **Syrinx:** Parrots, like other birds, have a syrinx (their voice box) which is far more complex and flexible than a mammal\'s larynx. Their syrinx has more muscles and allows for a wider range of sound production and manipulation.\n    *   **Tongue:** Unlike most birds that have thin, stiff tongues, parrots possess a thick, muscular, and agile tongue that they can manipulate to shape sounds, similar to how humans use their tongue for speech.\n    *   **Vocal Tract:** They can also modify the shape of their vocal tract (throat, mouth) to further alter the sounds they produce.\n\n2.  **Advanced Brain & Vocal Learning Centers:**\n    *   **Specialized Brain Regions:** Parrots have specific "vocal learning centers" in their brains. These regions are dedicated to processing and producing sounds, and they are highly developed and interconnected, allowing them to learn and imitate new sounds throughout their lives. This is a trait shared by only a few other animal groups (like songbirds, hummingbirds, whales, dolphins, and humans).\n    *   **Intelligence:** Parrots are highly intelligent birds, known for their problem-solving abilities and cognitive complexity. This intelligence allows them to not just mimic sounds, but sometimes to understand the context in which those sounds are used, associating words with objects or actions. Famous examples like Alex the African Grey parrot demonstrated remarkable understanding of concepts and vocabulary.\n\n3.  **Social Nature & Bonding:**\n    *   **Flock Animals:** Parrots are highly social creatures that live in large, complex flocks in the wild. Vocal communication is crucial for their survival and social cohesion.\n    *   **Integration and Identity:** In the wild, they learn flock-specific calls to identify members, warn of predators, and coordinate activities. Mimicry helps them integrate into the group.\n    *   **Mimicking the "Flock Leader":** When a parrot lives with humans, it often perceives its human companions as its "flock." To bond with its human "flock" and gain acceptance, it tries to mimic the sounds that its "flock members" make – human speech. It\'s a way for them to communicate, get attention, and feel like a part of the family.\n    *   **Attention Seeking:** If a parrot learns that making certain sounds (like human words) elicits a positive response or attention from its owners, it is more likely to repeat those sounds.\n\n4.  **Communication & Survival:**\n    *   Beyond mimicry, parrots use a wide range of their own natural vocalizations to communicate needs, express emotions (happiness, fear, frustration), and interact with their environment. Their ability to learn new sounds likely evolved to help them adapt to different social groups or environments in the wild.\n\nIn summary, parrots talk because they have the **physical machinery** to produce a wide range of sounds, the **brainpower** to learn and remember them, and a powerful **social drive** to communicate and bond with their flock, whether that flock consists of other parrots or humans.'

# %%
import os 
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model=init_chat_model("groq:llama-3.3-70b-versatile")
response=model.invoke("why do parrots talk?")
response
# Out:
# AIMessage(content='Parrots are known for their remarkable ability to mimic human speech and other sounds, but why do they talk in the first place? The answer lies in their evolution, social behavior, and communication needs.\n\n**Mimicry as a form of communication**\n\nIn the wild, parrots use vocalizations to communicate with each other. They make various sounds, such as chirps, whistles, and squawks, to convey information about food, predators, and social interactions. Mimicry is an extension of this communication system, allowing parrots to learn and reproduce sounds they hear in their environment.\n\n**Social learning and bonding**\n\nParrots are highly social birds that live in flocks in the wild. They learn to mimic sounds by observing and interacting with other parrots, as well as other animals and even their human caregivers. By mimicking sounds, parrots can:\n\n1. **Bond with their flock**: Mimicry helps parrots establish social connections and reinforce their position within the flock.\n2. **Learn about their environment**: By mimicking sounds, parrots can learn about potential threats, food sources, and other important aspects of their environment.\n3. **Get attention**: Parrots may mimic sounds to get attention from their caregivers or other parrots, which can lead to social interaction, food, or other rewards.\n\n**Brain structure and cognitive abilities**\n\nParrots have a unique brain structure that enables them to mimic sounds. Their syrinx, located at the base of the trachea, is a vocal organ that is capable of producing a wide range of sounds. Additionally, parrots have a large cortex-to-brain-mass ratio, which suggests a high level of cognitive ability and intelligence.\n\n**Why parrots mimic human speech**\n\nParrots are particularly skilled at mimicking human speech because of their:\n\n1. **Auditory system**: Parrots have a keen sense of hearing and can distinguish between subtle differences in sound.\n2. **Vocal anatomy**: Their syrinx and beak are adapted to produce a wide range of sounds, including those similar to human speech.\n3. **Cognitive abilities**: Parrots are intelligent birds that can learn to associate sounds with meanings and context.\n\nIn captivity, parrots may learn to mimic human speech as a way to:\n\n1. **Communicate with their caregivers**: Parrots may learn to mimic words or phrases to get attention, food, or other rewards.\n2. **Entertain themselves**: Parrots are known to be curious and playful, and mimicking human speech can be a form of entertainment.\n3. **Express themselves**: Parrots may use mimicry to express their emotions, such as happiness, boredom, or frustration.\n\nIn summary, parrots talk because it is an essential part of their communication system, social behavior, and cognitive abilities. By mimicking sounds, parrots can bond with their flock, learn about their environment, and even communicate with humans.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 592, 'prompt_tokens': 41, 'total_tokens': 633, 'completion_time': 1.536254997, 'completion_tokens_details': None, 'prompt_time': 0.001932387, 'prompt_tokens_details': None, 'queue_time': 0.057141303, 'total_time': 1.538187384}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e5959-75a8-7872-b7cc-09cfc94cd976-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 592, 'total_tokens': 633})

# %%
for chunk in model.stream("write me a 100 word paragraph on cars"):
    print(chunk.content, end="", flush=True)
# Out:
# Cars have revolutionized transportation, offering a convenient and efficient way to travel. With a wide range of models and brands available, there's a car to suit every need and budget. From sleek sports cars to practical family vehicles, cars provide freedom and flexibility. Advances in technology have improved safety features, fuel efficiency, and performance. Whether driving on the highway or navigating city streets, cars have become an integral part of modern life, providing a sense of independence and adventure for millions of people around the world, making them a staple of modern transportation and culture.

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end=" ", flush=True)
# Out:
# Artificial Intelligence (AI) refers to the development of computer systems  capable of performing tasks that typically require human intelligence. This encompasses learning from experience, understanding natural language, recognizing patterns, making decisions, and solving complex problems. Through sophisticated algorithms, machine learning models, and deep neural networks, AI empowers machines to  process enormous datasets, identify nuanced correlations, and generate predictive insights with remarkable accuracy.
#
# Its transformative impact is evident across virtually every sector, from powering personalized recommendations on streaming services and optimizing logistics in supply chains to revolutionizing medical diagnostics and enabling autonomous vehicles . In healthcare, AI assists in drug discovery and personalized treatment plans; in finance, it detects fraud and informs investment strategies; and in manufacturing, it enhances automation and quality control. AI's core promise lies in its ability to augment human  capabilities, boost efficiency, and tackle intricate global challenges that were once beyond our reach. As the field rapidly advances, it continues to reshape industries and daily life, prompting crucial discussions about its ethical implications, data privacy, and the responsible integration of  these intelligent systems into society.

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])

for response in responses:
    print (response)
# Out:
# content="Parrots have colorful feathers for several reasons:\n\n1. **Communication and Expression**: Parrots use their colorful feathers to communicate with other parrots. Different colors can signal emotions, intentions, and social status. For example, a parrot may display its brightest colors to attract a mate or to signal aggression.\n2. **Camouflage and Mimicry**: While parrots are known for their bright colors, some species have feathers that help them blend in with their surroundings. This is especially true for parrots that live in dense forests or among foliage. The colors and patterns on their feathers can help them mimic leaves, branches, or other natural features, making it harder for predators to spot them.\n3. **Thermoregulation**: The colors and structure of parrot feathers can help regulate their body temperature. Darker colors can absorb heat, while lighter colors can reflect it. This helps parrots maintain a stable body temperature, even in extreme environments.\n4. **Display and Courtship**: Many parrot species use their colorful feathers to impress potential mates. During courtship displays, parrots will often spread their colorful tails, wings, and crests to showcase their vibrant plumage. This helps attract a mate and establish dominance.\n5. **Evolutionary Advantage**: Brightly colored feathers may have evolved as a way to advertise a parrot's health, strength, and genetic quality to potential mates. Parrots with more vibrant colors may be perceived as more attractive and desirable, giving them an evolutionary advantage.\n6. **Visual Warning**: Some parrot species have brightly colored feathers that serve as a warning to potential predators. These colors can signal that the parrot is toxic, distasteful, or otherwise unpalatable, deterring predators from attacking them.\n\nIn summary, parrots' colorful feathers serve multiple purposes, including communication, camouflage, thermoregulation, display, and evolutionary advantage. These vibrant colors have evolved to help parrots survive, thrive, and attract mates in their environments." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 404, 'prompt_tokens': 43, 'total_tokens': 447, 'completion_time': 1.641367506, 'completion_tokens_details': None, 'prompt_time': 0.001233661, 'prompt_tokens_details': None, 'queue_time': 0.055593689, 'total_time': 1.642601167}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019e595f-68e9-7f80-9836-4de7cc7b6ba6-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 43, 'output_tokens': 404, 'total_tokens': 447}
# content="Airplanes fly by using a combination of four main forces: lift, weight, thrust, and drag. Here's a simplified explanation of how these forces work together to make an airplane fly:\n\n1. **Lift**: Lift is the upward force that opposes the weight of the airplane and keeps it flying. It's created by the shape of the wings, which are designed to produce a difference in air pressure above and below the wing. As the airplane moves forward, the air flows over and under the wing, creating an area of lower pressure above the wing and an area of higher pressure below it. This pressure difference creates an upward force, or lift, that helps the airplane rise into the air.\n2. **Weight**: Weight is the downward force that pulls the airplane towards the ground. It's the combined weight of the airplane itself, the passengers, cargo, and fuel.\n3. **Thrust**: Thrust is the forward force that propels the airplane through the air. It's created by the airplane's engines, which produce a stream of high-speed air that exits the back of the plane. As this air exits, it produces a forward force that counteracts the drag, or resistance, created by the air.\n4. **Drag**: Drag is the backward force that opposes the motion of the airplane. It's created by the friction between the airplane and the air, as well as the shape of the airplane itself. Drag slows down the airplane and makes it more difficult to fly.\n\nWhen an airplane is in flight, these four forces are in balance:\n\n* Lift opposes weight, keeping the airplane flying at a steady altitude.\n* Thrust opposes drag, keeping the airplane moving forward at a steady speed.\n\nTo generate lift, airplanes use a variety of techniques, including:\n\n* **Wing shape**: The curved upper surface of the wing deflects the air downward, creating a region of lower pressure above the wing.\n* **Angle of attack**: The wing is angled slightly upward, which creates a swirling motion behind the wing that helps to increase lift.\n* **Airfoil shape**: The wing is shaped like an airfoil, which is a curved surface that produces lift by changing the air pressure around it.\n\nTo generate thrust, airplanes use:\n\n* **Jet engines**: These engines produce a high-speed exhaust gas that exits the back of the plane, creating a forward force.\n* **Propellers**: These are spinning blades that push air backward, creating a forward force.\n\nOverall, the combination of lift, weight, thrust, and drag allows an airplane to fly by generating the upward force needed to counteract its weight, and the forward force needed to overcome drag and keep moving." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 539, 'prompt_tokens': 40, 'total_tokens': 579, 'completion_time': 1.30611654, 'completion_tokens_details': None, 'prompt_time': 0.001584029, 'prompt_tokens_details': None, 'queue_time': 0.05711758, 'total_time': 1.307700569}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019e595f-68ee-78a1-8dfc-5478b59f28ca-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 539, 'total_tokens': 579}
# content='**Introduction to Quantum Computing**\n=====================================\n\nQuantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform calculations and operations on data. It has the potential to solve complex problems that are currently unsolvable or require an unfeasible amount of time to solve using classical computers.\n\n**Key Concepts**\n---------------\n\n* **Qubits**: The basic unit of quantum information, analogous to classical bits. Qubits can exist in multiple states simultaneously, allowing for parallel processing of information.\n* **Superposition**: The ability of a qubit to exist in multiple states (0, 1, or both) at the same time.\n* **Entanglement**: The phenomenon where two or more qubits become connected, enabling the state of one qubit to affect the state of the other.\n* **Quantum gates**: The quantum equivalent of logic gates in classical computing, used to manipulate qubits and perform operations.\n\n**How Quantum Computing Works**\n------------------------------\n\n1. **Preparation**: Qubits are prepared in a specific state, often a superposition of 0 and 1.\n2. **Quantum gates**: Quantum gates are applied to the qubits to perform operations, such as rotations, entanglement, and measurements.\n3. **Evolution**: The qubits evolve according to the principles of quantum mechanics, allowing the system to explore an exponentially large solution space.\n4. **Measurement**: The qubits are measured, collapsing their superposition into a single outcome.\n\n**Advantages and Applications**\n-----------------------------\n\n* **Speedup**: Quantum computers can solve certain problems much faster than classical computers, such as factoring large numbers and simulating complex systems.\n* **Optimization**: Quantum computers can be used to optimize complex systems, such as logistics, finance, and energy management.\n* **Cryptography**: Quantum computers can break certain classical encryption algorithms, but they can also be used to create new, quantum-resistant encryption methods.\n* **Materials science**: Quantum computers can simulate the behavior of materials at the atomic level, leading to breakthroughs in fields like chemistry and materials engineering.\n\n**Current State and Challenges**\n-------------------------------\n\n* **Noise and error correction**: Quantum computers are prone to errors due to the noisy nature of quantum systems. Developing robust error correction methods is an active area of research.\n* **Scalability**: Currently, most quantum computers are small-scale and need to be scaled up to perform practical tasks.\n* **Quantum control**: Maintaining control over the quantum states of qubits is essential for reliable operation.\n\n**Conclusion**\n----------\n\nQuantum computing has the potential to revolutionize various fields by solving complex problems that are currently unsolvable or require an unfeasible amount of time to solve. While significant challenges remain, research and development are rapidly advancing the field, and we can expect to see significant breakthroughs in the coming years.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 573, 'prompt_tokens': 40, 'total_tokens': 613, 'completion_time': 1.306440789, 'completion_tokens_details': None, 'prompt_time': 0.001062082, 'prompt_tokens_details': None, 'queue_time': 0.055612778, 'total_time': 1.307502871}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019e595f-68f2-7863-aa9c-61133cc4035c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 573, 'total_tokens': 613}
